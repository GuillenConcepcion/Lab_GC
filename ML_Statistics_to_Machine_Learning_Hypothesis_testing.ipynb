# %% [markdown]
# <a href="https://colab.research.google.com/github/GuillenConcepcion/Lab_GC/blob/main/ML_Statistics_to_Machine_Learning_Hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Journey from Statistics to Machine Learning
#
# ##  hypothesis testing

# %% [markdown]
# # Library

# %%
from scipy import stats
import pandas as pd
import numpy as np

# %% [markdown]
# # Data

# %%
xbar = 990; mu0 = 1000; s = 12.5; n = 30

# %% [markdown]
# #Problem

# %% [markdown]
# ![Hypothesis  Testing.PNG](data:image/png;base64,...)

# %% [markdown]
# #Test Statistic

# %% [markdown]
# ## Hypothesis testing:
# This is the process of making inferences about the overall
#  population by conducting some statistical tests on a sample. Null and alternate
#  hypotheses are ways to validate whether an assumption is statistically significant  or not.

# %% [markdown]
# ## P-value:
#   The probability of obtaining a test statistic result is at least as extreme as
#   the one that was actually observed, assuming that the null hypothesis is true
#   (usually in modeling, against each independent variable, a **p-value less than 0.05**  is considered significant and greater than 0.05 is considered insignificant; nonetheless, these values and definitions may change with respect to context).

# %%
t_smple  = (xbar-mu0)/(s/np.sqrt(float(n)))
print ("Test Statistic:",round(t_smple,2))
# Out:
# Test Statistic: -4.38

# %% [markdown]
#  # Critical value from t-table

# %%
alpha = 0.05
t_alpha = stats.t.ppf(alpha,n-1); print ("Critical value from t-table:",round(t_alpha,3))
# Out:
# Critical value from t-table: -1.699

# %% [markdown]
# ![t Table.PNG](data:image/png;base64,...)

# %% [markdown]
# ![t.PNG](data:image/png;base64,...)

# %% [markdown]
# #Lower tail p-value from t-table

# %%
p_val = stats.t.sf(np.abs(t_smple), n-1); print ("Lower tail p-value from t-table", p_val)
# Out:
# Lower tail p-value from t-table 7.035025729010886e-05

# %%
 # Test statistic is -4.3818, which is less than the critical value of -1.699. Hence,
 # we can reject the null hypothesis (your friend's claim) that the mean weight
 # of a chocolate is above 1,000 g
